# %%
import tensorflow as tf
from tensorflow.keras.datasets import boston_housing
from sklearn import preprocessing

# %%
(train_x,train_y),(test_x,test_y)=boston_housing.load_data() #data loading
# Out:
# ...
# 57026/57026 [==============================] - 0s 0us/step

# %%
print("Training data sahpe:",train_x.shape)
print("Training data ouput shape:",train_y.shape)
print("Training data sahpe:",test_x.shape)
print("Training data ouput shape:",test_y.shape)
# train_x 404 recors having 13 values realted to the house like area,Number of rooms and train_y having 404 values for each 404 records
# Out:
# Training data sahpe: (404, 13)
# Training data ouput shape: (404,)
# Training data sahpe: (102, 13)
# Training data ouput shape: (102,)

# %%
train_x[0]
# Out:
# array([  1.23247,   0.     ,   8.14   ,   0.     ,   0.538  ,   6.142  ,
#         91.7    ,   3.9769 ,   4.     , 307.     ,  21.     , 396.9    ,
#         18.72   ])

# %%
train_y[0]
# Out:
# 15.2

# %%
#pre processing to make the 13 values in the 0 to 1 range
train_x=preprocessing.normalize(train_x)
test_x=preprocessing.normalize(test_x)

# %%
train_x[0]
# Out:
# array([0.0024119 , 0.        , 0.01592969, 0.        , 0.00105285,
#        0.01201967, 0.17945359, 0.00778265, 0.00782786, 0.6007879 ,
#        0.04109624, 0.77671895, 0.03663436])

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import *
#funtion which is buliding the model and compiling it
def HousePricePredictionModel():
 model =Sequential()
 model.add(Dense(128,activation='relu',input_shape=(train_x[0].shape)))
 model.add(Dense(64,activation='relu'))
 model.add(Dense(32,activation='relu'))
 model.add(Dense(1))
 model.compile(optimizer='rmsprop',loss='mse',metrics=['mae'])
 return model

# %%
model= HousePricePredictionModel()
history=model.fit(x=train_x,y=train_y,epochs=100,batch_size=1,verbose=1,validation_data=(test_x,test_y))
# with verbose we can see what is happing in each epoch
# Out:
# Epoch 1/100
# 404/404 [==============================] - 2s 3ms/step - loss: 113.2908 - mae: 7.7579 - val_loss: 83.9054 - val_mae: 6.5364
# Epoch 2/100
# 404/404 [==============================] - 1s 2ms/step - loss: 68.5444 - mae: 5.7781 - val_loss: 58.3290 - val_mae: 5.6381
# Epoch 3/100
# 404/404 [==============================] - 1s 2ms/step - loss: 62.4924 - mae: 5.5151 - val_loss: 55.6991 - val_mae: 5.4887
# Epoch 4/100
# 404/404 [==============================] - 1s 2ms/step - loss: 60.0124 - mae: 5.4541 - val_loss: 54.5851 - val_mae: 5.4073
# Epoch 5/100
# 404/404 [==============================] - 1s 3ms/step - loss: 58.6375 - mae: 5.2694 - val_loss: 56.9323 - val_mae: 5.3747
# Epoch 6/100
# 404/404 [==============================] - 1s 4ms/step - loss: 56.4745 - mae: 5.0367 - val_loss: 51.6514 - val_mae: 5.2003
# Epoch 7/100
# 404/404 [==============================] - 1s 2ms/step - loss: 54.7330 - mae: 5.0127 - val_loss: 53.6146 - val_mae: 5.1718
# Epoch 8/100
# ...

# %%
test_input = [[8.65407330e-05, 0.00000000e+00, 1.13392175e-02, 0.00000000e+00, 1.12518247e-03, 1.31897603e-02, 7.53763011e-02, 1.30768051e-02, 1.09241016e-02, 4.89399752e-01, 4.41333705e-02, 8.67155186e-01, 1.75004108e-02]]
print(model.predict(test_input))
# Out:
# 1/1 [==============================] - 0s 116ms/step
# [[21.666132]]
